# %%
import logging
#logging.basicConfig(level=logging.ERROR)

# %%
from Fred2.test import TestOptiTope, TestEpitopeAssembly
epi = TestEpitopeAssembly.EpitopeAssemblyTestCase()


epi.setUp()
epi.test_pareto_assembly()
# Out:
# WARNING:root:A*02:01 1.0
# WARNING:root:MODEL INSTANCE
# WARNING:root:6 Set Declarations
#     E : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'KLLPRLPGV', 'YLYDHLAPM', 'ALYDVVSTL'}
#     E_prime : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {'KLLPRLPGV', 'Dummy', 'YLYDHLAPM', 'ALYDVVSTL'}
#     ExE : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     2 :    Any :    6 : {('KLLPRLPGV', 'YLYDHLAPM'), ('KLLPRLPGV', 'ALYDVVSTL'), ('YLYDHLAPM', 'KLLPRLPGV'), ('YLYDHLAPM', 'ALYDVVSTL'), ('ALYDVVSTL', 'KLLPRLPGV'), ('ALYDVVSTL', 'YLYDHLAPM')}
#     e_ab_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain          : Size : Members
# ...

# %%
from Fred2.test import TestOptiTope, TestEpitopeAssembly
opti = TestOptiTope.OptiTopeTestCase()

opti.setUp()
opti.test_selection_without_constraints()
# Out:
# WARNING:pyomo.core:Initializing ordered Set Q with a fundamentally unordered data source (type: set).  This WILL potentially lead to nondeterministic behavior in Pyomo
# WARNING:pyomo.core:Initializing ordered Set E with a fundamentally unordered data source (type: set).  This WILL potentially lead to nondeterministic behavior in Pyomo
# WARNING:pyomo.core:Initializing ordered Set A_I with a fundamentally unordered data source (type: set).  This WILL potentially lead to nondeterministic behavior in Pyomo
# WARNING:pyomo.core:Initializing ordered Set A_I with a fundamentally unordered data source (type: set).  This WILL potentially lead to nondeterministic behavior in Pyomo
# WARNING: Initializing ordered Set Q with a fundamentally unordered data source
#     (type: set).  This WILL potentially lead to nondeterministic behavior in
#     Pyomo
# WARNING: Initializing ordered Set E with a fundamentally unordered data source
# ...
